# %% [markdown]
# # UNESCO Heritage Sites (2021)

# %% [markdown]
# ## Visualization of all UNESCO World Heritage Sites
#
# Date: 28/12/2021
#
# ## Dataset from [Kaggle](https://www.kaggle.com/ramjasmaurya/unesco-heritage-sites2021)
#
# ### Included in the dataset:
# * Description
# * Inscription date
# * Danger
# * Delisting date
# * Latitude
# * Longitude
# * Area (hectares)
# * Category
# * Country
# * Region
# * ISO code
# * Transboundary
# * Rev_bis

# %% [markdown]
# ## Imports

# %%
import pandas as pd

import seaborn as sns
sns.set_style("whitegrid")

import matplotlib.pyplot as plt
# %matplotlib inline

import geopandas as gpd

import folium 
from folium.plugins import HeatMap

import plotly.graph_objects as go
import plotly.express as px

# %% [markdown]
# ## Data prep

# %%
data = pd.read_csv("sites_2021.csv")
data.head()
# Out:
#                                         Name  \
# 0  L’Anse aux Meadows National Historic Site
# 1                      Nahanni National Park
# 2                          Galápagos Islands
# 3                              City of Quito
# 4                       Simien National Park
#
#                                    short_description  date_inscribed  danger  \
# 0  <p>At the tip of the Great Northern Peninsula ...            1978       0
# 1  <p>Located along the South Nahanni River, one ...            1978       0
# 2  <p>Situated in the Pacific Ocean some 1,000 km...            1978       0
# 3  <p>Quito, the capital of Ecuador, was founded ...            1978       0
# 4  <p>Massive erosion over the years on the Ethio...            1978       0
#
#    date_end   longitude   latitude  area_hectares category_long  \
# 0       NaN  -55.616667  51.466667        7991.00      Cultural
# 1       NaN -125.589444  61.547222      476560.00       Natural
# 2    2010.0  -90.501319  -0.689860    14066514.00       Natural
# 3       NaN  -78.512083  -0.220000          70.43      Cultural
# 4    2017.0   38.066667  13.183333       13600.00       Natural
#
#   category_short Country name                           Region iso_code  \
# 0              C       Canada         Europe and North America       ca
# 1              N       Canada         Europe and North America       ca
# 2              N      Ecuador  Latin America and the Caribbean       ec
# 3              C      Ecuador  Latin America and the Caribbean       ec
# 4              N     Ethiopia                           Africa       et
#
#    transboundary rev_bis
# 0              0     NaN
# 1              0     NaN
# 2              0     Bis
# 3              0     NaN
# 4              0     NaN

# %%
df = data[["Name","Country name","latitude","longitude","date_inscribed","danger","category_long","short_description","area_hectares"]]
df
# Out:
#                                                    Name  \
# 0             L’Anse aux Meadows National Historic Site
# 1                                 Nahanni National Park
# 2                                     Galápagos Islands
# 3                                         City of Quito
# 4                                  Simien National Park
# 5                          Rock-Hewn Churches, Lalibela
# 6                                     Aachen Cathedral
# 7                             Historic Centre of Kraków
# 8                Wieliczka and Bochnia Royal Salt Mines
# 9                                       Island of Gorée
# 10                             Mesa Verde National Park
# 11                            Yellowstone National Park
# 12                                        Boyana Church
# 13                                         Madara Rider
# 14                            Thracian Tomb of Kazanlak
# 15                        Rock-Hewn Churches of Ivanovo
# 16                             Dinosaur Provincial Park
# 17                                Old City of Dubrovnik
# 18    Historical Complex of Split with the Palace of...
# 19                         Plitvice Lakes National Park
# 1137  129.378333            2021       0       Natural
# 1138  140.552217            2021       0      Cultural
# 1139   35.728306            2021       0      Cultural
# 1140  -78.235917            2021       0      Cultural
# 1141  126.104444            2021       0       Natural
# 1142   23.130556            2021       1      Cultural
# 1143   36.012639            2021       0      Cultural
# 1144   44.545336            2021       0      Cultural
# 1145   14.502222            2021       0      Cultural
# 1146   -3.687056            2021       0      Cultural
# 1147   99.400167            2021       0       Natural
# 1148   38.361028            2021       0      Cultural
# 1149   -4.115000            2021       0      Cultural
# 1150  -55.766408            2021       0      Cultural
# 1151    5.866944            2021       0      Cultural
# 1152   16.861389            2021       0      Cultural
# 1153    6.391589            2021       0      Cultural
# 1154    4.433000            2021       0      Cultural
#
#                                       short_description  area_hectares
# 0     <p>At the tip of the Great Northern Peninsula ...   7.991000e+03
# 1     <p>Located along the South Nahanni River, one ...   4.765600e+05
# 2     <p>Situated in the Pacific Ocean some 1,000 km...   1.406651e+07
# 3     <p>Quito, the capital of Ecuador, was founded ...   7.043000e+01
# 4     <p>Massive erosion over the years on the Ethio...   1.360000e+04
# 5     <p>The 11 medieval monolithic cave churches of...   0.000000e+00
# 6     <p>Construction of this palatine chapel, with ...   2.000000e-01
# 7     <p>The Historic Centre of Kraków, the former c...   1.496500e+02
# 8     <p>The deposit of rock salt in Wieliczka and B...   1.104947e+03
# 9     <p>The island of Gor&eacute;e lies off the coa...   0.000000e+00
# 10    <p>A great concentration of ancestral Pueblo I...   2.104300e+04
# 11    <p>The vast natural forest of Yellowstone Nati...   8.983490e+05
# 12    <p>Located on the outskirts of Sofia, Boyana C...   6.800000e-01
# 13    <p>The Madara Rider, representing the figure o...   1.200000e+00
# 14    <p>Discovered in 1944, this tomb dates from th...   1.550000e-02
# 15    <p>In the valley of the Roussenski Lom River, ...   1.719000e+02
# 16    <p>In addition to its particularly beautiful s...   7.825000e+03
# 17    <p>The 'Pearl of the Adriatic', situated on th...   9.670000e+01
# 18    <p>The ruins of Diocletian's Palace, built bet...   2.080000e+01
# 19    <p>The waters flowing over the limestone and c...   2.963077e+04
# 20    <p>Virunga National Park (covering an area of ...   8.000000e+05
# 21    <p>The capital of the Old Kingdom of Egypt has...   1.635852e+04
# 22    <p>Thebes, the city of the god Amon, was the c...   7.390160e+03
# 23    <p>This outstanding archaeological area contai...   3.744800e+02
# 24    <p>Tucked away amid the modern urban area of C...   5.236600e+02
# 25    <p>The church, baptistry, basilicas, public bu...   1.827200e+02
# 26    <p>In the 16th and 17th centuries, the fortres...   0.000000e+00
# 27    <p>Perched on a rocky islet in the midst of va...   6.560000e+03
# 28    <p>Partly built starting in 1145, and then rec...   1.060000e+00
# 29    <p>The Palace of Versailles was the principal ...   1.070000e+03
# ...                                                 ...            ...
# 1125  The Lighthouse of Cordouan rises up on a shall...   1.701510e+04
# 1126  <p>The Mediterranean city Nice, near the Itali...            NaN
# 1127  <p>Situated on the equator in northern Gabon t...   2.987580e+05
# 1128  <p>The site comprises seven component parts, w...   3.125300e+04
# 1129  The Darmstadt Artists’ Colony on Mathildenhöh...   5.370000e+00
# 1130  <p>Located in the former Imperial cathedral ci...   5.560000e+00
# 1131  Rudreshwara, popularly known as Ramappa Temple...   5.930000e+00
# 1132  <p>The ancient city of Dholavira, the southern...   1.030000e+02
# 1133  The Trans-Iranian Railway connects the Caspian...   5.784000e+03
# 1134  <p>The remote and mountainous landscape of Haw...   1.063070e+05
# 1135  The site is composed of eight religious and se...   1.996000e+01
# 1136  <p>The serial property comprises twelve compon...   5.218000e+01
# 1137  <p>Encompassing 42,698 hectares of subtropical...   4.269800e+04
# 1138  <p>The property consists of 17 archaeological ...   1.419000e+02
# 1139  <p>Built on three closely-spaced hills in the ...   2.468000e+01
# 1140  <p>The Chankillo Archaeoastronomical Complex i...   4.480000e+03
# 1141  <p>Situated in the eastern Yellow Sea on the s...   1.284110e+05
# 1142  Located in the Metalliferous range of the Apus...            NaN
# 1143  <p>The site contains 4,500 petroglyphs carved ...   7.049540e+03
# 1144  <p>Located in an arid, mountainous area of sou...   2.421700e+02
# 1145  <p>The work Jože Plečnik carried in Ljubljana ...            NaN
# 1146  Located at the urban heart of Madrid, the 200-...   2.189100e+02
# 1147  <p>The site is located along the Thailand side...   4.089400e+05
# 1148  <p>Arslantepe Mound is a 30-metre-tall archaeo...   4.850000e+00
# 1149  <p>The Slate Landscape of Northwest Wales illu...   3.259010e+03
# 1150  <p>The Church of Atlántida with its belfry and...   5.600000e-01
# 1151  The transnational site of The Great Spa Towns ...   7.014000e+03
# 1152  <p>It covers almost 600km of the whole Roman E...            NaN
# 1153  <p>The transnational serial property encompass...   2.012000e+03
# 1154  <p>Following the left bank of the Lower Rhine ...            NaN
#
# [1155 rows x 9 columns]

# %% [markdown]
# ### Set location

# %%
coord = df[["latitude","longitude"]]

# %%
coord.head()
# Out:
#     latitude   longitude
# 0  51.466667  -55.616667
# 1  61.547222 -125.589444
# 2  -0.689860  -90.501319
# 3  -0.220000  -78.512083
# 4  13.183333   38.066667

# %%
coord.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 2 columns):
# latitude     1155 non-null float64
# longitude    1155 non-null float64
# dtypes: float64(2)
# memory usage: 18.1 KB

# %%
coord.describe()
# Out:
#           latitude    longitude
# count  1155.000000  1155.000000
# mean     28.993328    20.621723
# std      23.687112    62.819560
# min     -54.594722  -179.715278
# 25%      17.510276    -3.272826
# 50%      36.126667    16.314440
# 75%      45.767777    50.520000
# max      71.188889   178.834533

# %% [markdown]
# ### Drop NaN

# %%
coord = coord.dropna()

# %%
coord.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1155 entries, 0 to 1154
# Data columns (total 2 columns):
# latitude     1155 non-null float64
# longitude    1155 non-null float64
# dtypes: float64(2)
# memory usage: 27.1 KB

# %% [markdown]
# ## Heritage Site Heatmap

# %%
lat = coord["latitude"].mean()
long = coord["longitude"].mean()

# %%
hmap = folium.Map(location=[lat,long],zoom_start=2)
hmap.add_child(HeatMap(coord, radius = 15))

hmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_17713d63e6604a1f98b14c51561cb511%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_17713d63e6604a1f98b14c51561cb511%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_17713d63e6604a1f98b14c51561cb511%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_17713d63e6604a1f98b14c51561cb511%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...

# %% [markdown]
# ## All Sites

# %%
popmap = folium.Map(location=[20, 0], tiles="stamenterrain", zoom_start=2)

for i in range(0,len(df)):
    folium.Marker([df.iloc[i]["latitude"], df.iloc[i]["longitude"]], popup=df.iloc[i][["Name","category_long"]]).add_to(popmap)
    
popmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e1f4f8dec0a04172a3fdd5e072029019%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e1f4f8dec0a04172a3fdd5e072029019%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e1f4f8dec0a04172a3fdd5e072029019%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e1f4f8dec0a04172a3fdd5e072029019%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B20.0%2C%200.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs ...

# %% [markdown]
# ## Heritage Site Distribution per Country

# %%
df["Country name"].value_counts()
pass

# %%
df["countries_short"] = df["Country name"].apply(lambda x: str(x[0:31]))
df["countries_short"].value_counts()
pass
# Out:
# C:\Users\Ece\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(20,9))
df["countries_short"].value_counts()[:20].plot(kind="bar", color="C1", alpha=0.4, grid=False)
  
for index, value in enumerate(df["countries_short"].value_counts()[:20]):
    plt.text(index, value, str(value))
plt.xlabel("Countries", fontsize=15)
plt.ylabel("Number of sites", fontsize=15)
plt.title("World Heritage Site distribution per country (Top 20)", fontsize=20)
plt.show()

# %% [markdown]
# ## Heritage Sites by Category

# %%
df2 = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df["longitude"], df["latitude"]))
df2.crs = {"init": "epsg:4326"}
wmap = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
df2.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 12 columns):
# Name                 1155 non-null object
# Country name         1155 non-null object
# latitude             1155 non-null float64
# longitude            1155 non-null float64
# date_inscribed       1155 non-null int64
# danger               1155 non-null int64
# category_long        1155 non-null object
# short_description    1155 non-null object
# area_hectares        1135 non-null float64
# countries            1155 non-null object
# countries_short      1155 non-null object
# geometry             1155 non-null geometry
# dtypes: float64(3), geometry(1), int64(2), object(6)
# memory usage: 108.4+ KB

# %%
ax = wmap.plot(figsize=(20,20),color="lightgray")
df2.groupby("category_long")["geometry"].plot(ax=ax,marker=".", markersize=20, alpha=1)
plt.title("UNESCO Heritage Sites by Category", fontsize=20)
plt.show()

# %% [markdown]
# ### Legend
#
# **Green:** Natural
#
# **Blue:** Cultural
#
# **Orange:** Mixed

# %% [markdown]
# ## Threatened sites

# %%
df["danger"].value_counts()
# Out:
# 0    1103
# 1      52
# Name: danger, dtype: int64

# %%
ax = wmap.plot(figsize=(20,20),color="lightgray")
df2.groupby("danger")["geometry"].plot(ax=ax,marker=".", markersize=20, alpha=1)
plt.title("Threatened Heritage Sites", fontsize=20)
plt.show()

# %% [markdown]
# ### Legend
#
# **Blue:** Safe
#
# **Orange:** Endangered
